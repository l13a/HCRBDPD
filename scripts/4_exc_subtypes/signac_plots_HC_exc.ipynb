# %%
library(Signac)
library(Seurat)
library(EnsDb.Hsapiens.v86)
library(SeuratDisk)
library(dplyr)
library(BSgenome.Hsapiens.UCSC.hg38)
# Out:
# Warning message:
# “package ‘Signac’ was built under R version 4.3.3”
# Warning message:
# “package ‘Seurat’ was built under R version 4.3.3”
# Loading required package: SeuratObject
#
# Warning message:
# “package ‘SeuratObject’ was built under R version 4.3.3”
# Loading required package: sp
#
# Warning message:
# “package ‘sp’ was built under R version 4.3.3”
#
# Attaching package: ‘SeuratObject’
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, t
#
#
# Loading required package: ensembldb
#
# Warning message:
# “package ‘ensembldb’ was built under R version 4.3.2”
# Loading required package: BiocGenerics
#
# Warning message:
# “package ‘BiocGenerics’ was built under R version 4.3.2”
#
# Attaching package: ‘BiocGenerics’
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     intersect
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: GenomicRanges
#
# Warning message:
# “package ‘GenomicRanges’ was built under R version 4.3.3”
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
# Warning message:
# “package ‘S4Vectors’ was built under R version 4.3.3”
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Warning message:
# “package ‘IRanges’ was built under R version 4.3.3”
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:sp’:
#
#     %over%
#
#
# Loading required package: GenomeInfoDb
#
# Warning message:
# “package ‘GenomeInfoDb’ was built under R version 4.3.2”
# Loading required package: GenomicFeatures
#
# Warning message:
# “package ‘GenomicFeatures’ was built under R version 4.3.2”
# Loading required package: AnnotationDbi
#
# Warning message:
# “package ‘AnnotationDbi’ was built under R version 4.3.2”
# Loading required package: Biobase
#
# Warning message:
# “package ‘Biobase’ was built under R version 4.3.3”
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: AnnotationFilter
#
# Warning message:
# “package ‘AnnotationFilter’ was built under R version 4.3.2”
#
# Attaching package: 'ensembldb'
#
#
# The following object is masked from 'package:stats':
#
#     filter
#
#
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat
#
# Warning message:
# "package 'dplyr' was built under R version 4.3.3"
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:ensembldb':
#
#     filter, select
#
#
# The following object is masked from 'package:AnnotationDbi':
#
#     select
#
#
# The following object is masked from 'package:Biobase':
#
#     combine
#
#
# The following objects are masked from 'package:GenomicRanges':
#
#     intersect, setdiff, union
#
#
# The following object is masked from 'package:GenomeInfoDb':
#
#     intersect
#
#
# The following objects are masked from 'package:IRanges':
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from 'package:S4Vectors':
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from 'package:BiocGenerics':
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: BSgenome
#
# Warning message:
# "package 'BSgenome' was built under R version 4.3.2"
# Loading required package: Biostrings
#
# Warning message:
# "package 'Biostrings' was built under R version 4.3.3"
# Loading required package: XVector
#
# Warning message:
# "package 'XVector' was built under R version 4.3.3"
#
# Attaching package: 'Biostrings'
#
#
# The following object is masked from 'package:base':
#
#     strsplit
#
#
# Loading required package: BiocIO
#
# Warning message:
# "package 'BiocIO' was built under R version 4.3.2"
# Loading required package: rtracklayer
#
# Warning message:
# "package 'rtracklayer' was built under R version 4.3.3"
#
# Attaching package: 'rtracklayer'
#
#
# The following object is masked from 'package:BiocIO':
#
#     FileForFormat

# %%
ifnb <- readRDS("hc_processed_rna+atac.rds")

# %%
ifnb <- subset(ifnb, celltype == "excitatory neurons")

# %%
DefaultAssay(ifnb) <- "ATAC"
# first compute the GC content for each peak
ifnb <- RegionStats(ifnb, genome = BSgenome.Hsapiens.UCSC.hg38)
# Out:
# Warning message in RegionStats.default(object = regions, genome = genome, verbose = verbose, :
# "Not all seqlevels present in supplied genome"

# %%
idents.plot <- c('excitatory neurons')
Idents(ifnb) <- idents.plot

# %%
ifnb
# Out:
# An object of class Seurat
# 333440 features across 7739 samples within 3 assays
# Active assay: ATAC (265980 features, 247295 variable features)
#  2 layers present: counts, data
#  2 other assays present: RNA, SCT
#  2 dimensional reductions calculated: pca, lsi

# %% [markdown]
# ### Helper

# %%
library(ggplot2)
save_link_counts <- function(ifnb, gene_list, file_prefix){
    # link peaks to genes
    ifnb <- LinkPeaks(
      object = ifnb,
      peak.assay = "ATAC",
      expression.assay = "SCT",
      genes.use = gene_list
    )

    peak_gene_links <- Links(ifnb[["ATAC"]])
    df <- as.data.frame(peak_gene_links)

    gene_link_counts <- df %>%
      filter(pvalue < 0.05) %>%
      group_by(gene) %>%
      summarise(link_count = n())

    write.csv(gene_link_counts, paste0(file_prefix, "gene_link_counts.csv"), row.names = FALSE)
    
    # Return both the original df and gene_link_counts as a list
    return(list(df = df, gene_link_counts = gene_link_counts))
}
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.3.3"

# %%
library(Signac)
library(patchwork)   # lets us manipulate the assembled plot
library(ggplot2)

plot_coverage <- function(ifnb, gene_list, file_prefix,
                          idents.plot = NULL,
                          extend.up = 5e4, extend.down = 5e5) {

  DefaultAssay(ifnb) <- "ATAC"
  ifnb <- LinkPeaks(ifnb,
                    peak.assay       = "ATAC",
                    expression.assay = "SCT",
                    genes.use        = gene_list)

  for (g in gene_list) {
    message("Plotting ", g)

    tryCatch({

      cov <- CoveragePlot(
             ifnb,
             region            = g,
             features          = g,
             expression.assay  = "SCT",
             links             = FALSE,
             link.assay        = "ATAC",
             idents            = idents.plot,
             extend.upstream   = extend.up,
             extend.downstream = extend.down
           )
       arc  <- LinkPlot(ifnb, region = g, assay = "ATAC",
                  extend.upstream = 5e4, extend.downstream = 5e5) +
       scale_colour_gradient2(low = "blue", mid = "grey",
                               high = "#ca0020", midpoint = 0,
                               limits = c(-0.1, 0.1), name = "Link\nscore") +
        guides(colour = guide_colourbar(title.position = "top")) +
        theme(legend.position = "right")

       final <- cov / arc

       ggsave(paste0(file_prefix, g, ".pdf"), final, width = 15, height = 6)

    }, error = function(e) {
      message("Skipping ", g, ": ", e$message)
    })
  }
}

# %% [markdown]
# ### RORB Marker Genes

# %%
library(readxl)
library(dplyr)

top_genes <- c()
# Define file path
file_path <- "../../Annotate_Exc_Subtype/RORB_cells/Marker_Genes.xlsx"

sheet_names <- excel_sheets(file_path)
all_sheets <- lapply(sheet_names, function(sheet) {
  read_excel(file_path, sheet = sheet)
})
names(all_sheets) <- sheet_names

for (name in sheet_names){
    print(name)
    gene_data <- all_sheets[[name]]
    # Ensure column names are correctly recognized
    colnames(gene_data) <- c("gene", "p_val", "avg_log2FC", "pct.1", "pct.2", "p_val_adj")

    # Filter genes based on criteria: p_val_adj < 0.001 and avg_log2FC > 0.25
    filtered_genes <- gene_data %>%
      filter(p_val_adj < 0.001, avg_log2FC > 2)
    
    top_genes <- c(top_genes, as.vector(filtered_genes$gene))
}
# Out:
# Warning message:
# "package 'readxl' was built under R version 4.3.3"
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# [1] "Exc L4-5 RORB LCN15"
# [1] "Exc L3-4 RORB SEMA6D"
# [1] "Exc L3-5 RORB HSPB3"
# [1] "Exc L4-5 RORB HNRNPA1P46"
# [1] "Exc L3-4 RORB FOLH1B"
# [1] "Exc L2-4 RORB GRIK1"
# [1] "Exc L4-5 RORB RPL31P31"
# [1] "Exc L4-5 RORB LINC01474"
# [1] "Exc L3-5 RORB CMAHP"
# [1] "Exc L3-4 RORB PRSS12"
# [1] "Exc L5 RORB LINC01202"
# [1] "Exc L5 RORB SNHG7"
# [1] "Exc L3 RORB CARTPT"
# [1] "Exc L3-5 RORB CD24"
# [1] "Exc L5-6 RORB LINC00320"
# [1] "Exc L4-6 RORB HPCA"

# %%
length(top_genes)
# Out:
# [1] 1399

# %%
file_prefix <- "../../Signac_plots/HC/Marker_Genes_RORB_exn/"

# Create the directory if it doesn't exist
if (!dir.exists(file_prefix)) {
  dir.create(file_prefix, recursive = TRUE)  # 'recursive = TRUE' ensures parent directories are created if needed
  message(paste("Directory created:", file_prefix))
} else {
  message(paste("Directory already exists:", file_prefix))
}

omit <- save_link_counts(ifnb, top_genes, file_prefix)
# Out:
# Directory already exists: ../Signac_plots/HC/Marker_Genes_RORB_exn/
#
# Testing 577 genes and 148617 peaks
#
# Found gene coordinates for 354 genes
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "Each of the 2 combined objects has sequence levels not in the other:
#   - in 'x': GL000194.1, GL000195.1, GL000205.2, GL000218.1, GL000219.1, KI270711.1, KI270713.1, KI270721.1, KI270726.1, KI270727.1, KI270728.1, KI270731.1, KI270734.1, GL000009.2, GL000213.1
#   - in 'y': chrMT
#   Make sure to always combine/compare objects based on the same reference
#   genome (use suppressWarnings() to suppress this warning)."

# %%
file_prefix <- "../../Signac_plots/HC/Marker_Genes_RORB_exn/"

# Create the directory if it doesn't exist
if (!dir.exists(file_prefix)) {
  dir.create(file_prefix, recursive = TRUE)  # 'recursive = TRUE' ensures parent directories are created if needed
  message(paste("Directory created:", file_prefix))
} else {
  message(paste("Directory already exists:", file_prefix))
}

plot_coverage(ifnb, top_genes, file_prefix)
# Out:
# Directory already exists: ../Signac_plots/HC/Marker_Genes_RORB_exn/
#
# Testing 577 genes and 148617 peaks
#
# Found gene coordinates for 354 genes
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "Each of the 2 combined objects has sequence levels not in the other:
#   - in 'x': GL000194.1, GL000195.1, GL000205.2, GL000218.1, GL000219.1, KI270711.1, KI270713.1, KI270721.1, KI270726.1, KI270727.1, KI270728.1, KI270731.1, KI270734.1, GL000009.2, GL000213.1
#   - in 'y': chrMT
#   Make sure to always combine/compare objects based on the same reference
#   genome (use suppressWarnings() to suppress this warning)."
# Plotting TLL1
#
# Plotting GRIN3A
#
# Warning message:
# "Removed 7 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting COL21A1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RBM20
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 27 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting NOX4
#
# Warning message:
# "Removed 6 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CMTM8
#
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AP003400.1
#
# Skipping AP003400.1: Gene not found
#
# Plotting RSPO3
#
# Plotting PCP4
#
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01320
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL589693.1
#
# Skipping AL589693.1: Gene not found
#
# Plotting MYBPC1
#
# Warning message:
# "Removed 12 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL445207.1
#
# Skipping AL445207.1: Gene not found
#
# Plotting CACNG5
#
# Warning message:
# "Removed 90 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC113137.1
#
# Skipping AC113137.1: Gene not found
#
# Plotting EGF
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 31 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ADRA1A
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 175 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL158835.1
#
# Skipping AL158835.1: Gene not found
#
# Plotting NDST4
#
# Plotting AC079163.2
#
# Skipping AC079163.2: Gene not found
#
# Plotting DPP10-AS3
#
# Skipping DPP10-AS3: Gene not found
#
# Plotting AF064860.1
#
# Skipping AF064860.1: Gene not found
#
# Plotting PCP4L1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 45 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC092546.1
#
# Skipping AC092546.1: Gene not found
#
# Plotting IGSF5
#
# Warning message:
# "Removed 20 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC105213.1
#
# Skipping AC105213.1: Gene not found
#
# Plotting PROKR2
#
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AGBL1
#
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting COL13A1
#
# Plotting TYR
#
# Plotting AL161629.1
#
# Skipping AL161629.1: Gene not found
#
# Plotting PPP3R2
#
# Warning message:
# "Removed 20 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01090
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting TMC5
#
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ONECUT1
#
# Warning message:
# "Removed 104 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting NPY2R
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 32 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC122697.1
#
# Skipping AC122697.1: Gene not found
#
# Plotting LINC00939
#
# Plotting RHEX
#
# Skipping RHEX: Gene not found
#
# Plotting NIBAN1
#
# Skipping NIBAN1: Gene not found
#
# Plotting AL449363.2
#
# Skipping AL449363.2: Gene not found
#
# Plotting CLPSL1
#
# Warning message:
# "Removed 26 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC021134.2
#
# Skipping AC021134.2: Gene not found
#
# Plotting LINC00383
#
# Warning message:
# "Removed 13 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL353052.1
#
# Skipping AL353052.1: Gene not found
#
# Plotting DPP10-AS2
#
# Skipping DPP10-AS2: Gene not found
#
# Plotting BMP5
#
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting BHMT
#
# Warning message:
# "Removed 128 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting GIMAP4
#
# Warning message:
# "Removed 35 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC023781.1
#
# Skipping AC023781.1: Gene not found
#
# Plotting AP000248.1
#
# Skipping AP000248.1: Gene not found
#
# Plotting LINC01204
#
# Plotting AC002066.1
#
# Skipping AC002066.1: Gene not found
#
# Plotting ADGRF5
#
# Warning message:
# "Removed 9 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC011351.1
#
# Skipping AC011351.1: Gene not found
#
# Plotting AC095050.1
#
# Skipping AC095050.1: Gene not found
#
# Plotting NMUR2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 12 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CAV1
#
# Warning message:
# "Removed 319 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC007218.1
#
# Skipping AC007218.1: Gene not found
#
# Plotting PCSK6
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 13 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting F11-AS1
#
# Skipping F11-AS1: Gene not found
#
# Plotting GPR26
#
# Plotting CNGB1
#
# Warning message:
# "Removed 657 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SAMD3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 380 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01445
#
# Plotting AC092848.2
#
# Skipping AC092848.2: Gene not found
#
# Plotting HCN4
#
# Warning message:
# "Removed 89 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LCP2
#
# Warning message:
# "Removed 18 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01781
#
# Skipping LINC01781: Gene not found
#
# Plotting AL359924.1
#
# Skipping AL359924.1: Gene not found
#
# Plotting CFAP58
#
# Warning message:
# "Removed 88 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC090503.2
#
# Skipping AC090503.2: Gene not found
#
# Plotting AL353753.1
#
# Skipping AL353753.1: Gene not found
#
# Plotting POU3F1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting AL136234.1
#
# Skipping AL136234.1: Gene not found
#
# Plotting CYSLTR1
#
# Plotting AC093898.1
#
# Skipping AC093898.1: Gene not found
#
# Plotting AL359095.1
#
# Skipping AL359095.1: Gene not found
#
# Plotting MMEL1
#
# Warning message:
# "Removed 102 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC079942.1
#
# Skipping AC079942.1: Gene not found
#
# Plotting AC099568.1
#
# Skipping AC099568.1: Gene not found
#
# Plotting AC093519.2
#
# Skipping AC093519.2: Gene not found
#
# Plotting LINC02445
#
# Skipping LINC02445: Gene not found
#
# Plotting CHRNA6
#
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OR13C5
#
# Plotting MCOLN2
#
# Warning message:
# "Removed 15 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL137026.3
#
# Skipping AL137026.3: Gene not found
#
# Plotting LINC02388
#
# Skipping LINC02388: Gene not found
#
# Plotting AC103843.1
#
# Skipping AC103843.1: Gene not found
#
# Plotting LINC00488
#
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC092661.1
#
# Skipping AC092661.1: Gene not found
#
# Plotting AC114954.1
#
# Skipping AC114954.1: Gene not found
#
# Plotting APOC4
#
# Warning message:
# "Removed 14 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting HSPB3
#
# Warning message:
# "Removed 13 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting NPNT
#
# Warning message:
# "Removed 130 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC080079.2
#
# Skipping AC080079.2: Gene not found
#
# Plotting C10orf90
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 130 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ADAMTSL1
#
# Warning message:
# "Removed 5 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SILC1
#
# Skipping SILC1: Gene not found
#
# Plotting RASSF6
#
# Warning message:
# "Removed 87 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting BARX2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 19 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SCN5A
#
# Warning message:
# "Removed 37 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ADAM12
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CNGB3
#
# Warning message:
# "Removed 116 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL133346.1
#
# Skipping AL133346.1: Gene not found
#
# Plotting ANKRD34B
#
# Warning message:
# "Removed 76 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting WHRN
#
# Warning message:
# "Removed 47 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ADAMTS12
#
# Plotting AC111006.1
#
# Skipping AC111006.1: Gene not found
#
# Plotting INTS12
#
# Warning message:
# "Removed 11 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01137
#
# Skipping LINC01137: Gene not found
#
# Plotting TCF7L1
#
# Plotting KIT
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting AL807742.1
#
# Skipping AL807742.1: Gene not found
#
# Plotting LINC01013
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting LINC02499
#
# Skipping LINC02499: Gene not found
#
# Plotting SHB
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 21 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ERG
#
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RELN
#
# Warning message:
# "Removed 240 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01179
#
# Plotting PARP12
#
# Warning message:
# "Removed 207 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC113137.1
#
# Skipping AC113137.1: Gene not found
#
# Plotting AL021408.1
#
# Skipping AL021408.1: Gene not found
#
# Plotting APELA
#
# Warning message:
# "Removed 20 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting GFRA1
#
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TFPI
#
# Warning message:
# "Removed 62 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting WNT4
#
# Warning message:
# "Removed 11 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CCND1
#
# Warning message:
# "Removed 52 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting NPSR1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 11 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting F2RL2
#
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting NHLH2
#
# Plotting LINC00601
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 175 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC124254.2
#
# Skipping AC124254.2: Gene not found
#
# Plotting AL589787.1
#
# Skipping AL589787.1: Gene not found
#
# Plotting AL391832.2
#
# Skipping AL391832.2: Gene not found
#
# Plotting AL356413.1
#
# Skipping AL356413.1: Gene not found
#
# Plotting HLA-DPA1
#
# Plotting FEZF2
#
# Warning message:
# "Removed 55 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC005592.1
#
# Warning message:
# "Removed 54 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC105213.1
#
# Skipping AC105213.1: Gene not found
#
# Plotting AL031073.2
#
# Skipping AL031073.2: Gene not found
#
# Plotting IFNG-AS1
#
# Skipping IFNG-AS1: Gene not found
#
# Plotting SLITRK6
#
# Plotting LINC02067
#
# Skipping LINC02067: Gene not found
#
# Plotting TNN
#
# Warning message:
# "Removed 8 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC109361.2
#
# Skipping AC109361.2: Gene not found
#
# Plotting SCUBE1
#
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL356361.2
#
# Skipping AL356361.2: Gene not found
#
# Plotting AC096589.1
#
# Skipping AC096589.1: Gene not found
#
# Plotting GALR1
#
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting BTBD16
#
# Warning message:
# "Removed 156 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PODN
#
# Warning message:
# "Removed 91 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SV2C
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC004158.1
#
# Warning message:
# "Removed 15 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting FKBP5
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 15 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TRPC6
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 38 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ROBO1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting GLIS3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 13 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SPOCK3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting TESPA1
#
# Plotting MOXD1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting PDZD2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting SLC24A4
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 33 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ITGA9
#
# Warning message:
# "Removed 6 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ITPR2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 142 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting COL24A1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 8 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting STXBP6
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting SH3RF2
#
# Warning message:
# "Removed 144 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TXK
#
# Warning message:
# "Removed 101 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting INSYN2B
#
# Skipping INSYN2B: Gene not found
#
# Plotting GYG2
#
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CTXN3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 55 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting BCL11B
#
# Warning message:
# "Removed 154 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL138694.1
#
# Skipping AL138694.1: Gene not found
#
# Plotting AC110014.1
#
# Skipping AC110014.1: Gene not found
#
# Plotting LINC02552
#
# Skipping LINC02552: Gene not found
#
# Plotting DCHS2
#
# Plotting ANKRD30A
#
# Plotting CCBE1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ACVR1C
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 46 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TEC
#
# Warning message:
# "Removed 24 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ANKRD62
#
# Warning message:
# "Removed 17 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC105450.1
#
# Skipping AC105450.1: Gene not found
#
# Plotting LINC01605
#
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TOX3
#
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC024145.1
#
# Skipping AC024145.1: Gene not found
#
# Plotting LINC01478
#
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting DOCK2
#
# Warning message:
# "Removed 77 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02720
#
# Skipping LINC02720: Gene not found
#
# Plotting AC022509.2
#
# Skipping AC022509.2: Gene not found
#
# Plotting LCP2
#
# Warning message:
# "Removed 18 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC138646.1
#
# Skipping AC138646.1: Gene not found
#
# Plotting CDH18-AS1
#
# Skipping CDH18-AS1: Gene not found
#
# Plotting SLC5A8
#
# Warning message:
# "Removed 137 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02073
#
# Skipping LINC02073: Gene not found
#
# Plotting AL020994.2
#
# Skipping AL020994.2: Gene not found
#
# Plotting MFGE8
#
# Warning message:
# "Removed 53 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL139379.1
#
# Skipping AL139379.1: Gene not found
#
# Plotting AC092353.2
#
# Skipping AC092353.2: Gene not found
#
# Plotting TMEM244
#
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SYT2
#
# Warning message:
# "Removed 104 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02015
#
# Skipping LINC02015: Gene not found
#
# Plotting AC087636.1
#
# Skipping AC087636.1: Gene not found
#
# Plotting WDR86
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting ST8SIA6
#
# Warning message:
# "Removed 43 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SLC47A1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 123 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting DHRS3
#
# Plotting AP006295.1
#
# Skipping AP006295.1: Gene not found
#
# Plotting AC113404.1
#
# Warning message:
# "Removed 68 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL162872.1
#
# Skipping AL162872.1: Gene not found
#
# Plotting ACAN
#
# Warning message:
# "Removed 58 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL450313.1
#
# Skipping AL450313.1: Gene not found
#
# Plotting IMPA2
#
# Warning message:
# "Removed 33 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL669970.1
#
# Skipping AL669970.1: Gene not found
#
# Plotting LINC00836
#
# Warning message:
# "Removed 36 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LAMP5
#
# Warning message:
# "Removed 322 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AJ003147.2
#
# Skipping AJ003147.2: Gene not found
#
# Plotting GC
#
# Warning message:
# "Removed 40 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01100
#
# Warning message:
# "Removed 8 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC005100.1
#
# Skipping AC005100.1: Gene not found
#
# Plotting QRFPR
#
# Warning message:
# "Removed 43 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AP003398.2
#
# Skipping AP003398.2: Gene not found
#
# Plotting IL15RA
#
# Warning message:
# "Removed 51 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting KLHL14
#
# Warning message:
# "Removed 94 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SMPX
#
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC103982.1
#
# Skipping AC103982.1: Gene not found
#
# Plotting TPO
#
# Warning message:
# "Removed 91 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02336
#
# Skipping LINC02336: Gene not found
#
# Plotting AC008568.1
#
# Skipping AC008568.1: Gene not found
#
# Plotting MUCL1
#
# Plotting OLFM4
#
# Plotting LNCTAM34A
#
# Skipping LNCTAM34A: Gene not found
#
# Plotting SLC12A3
#
# Warning message:
# "Removed 56 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CIDEA
#
# Plotting AC005323.2
#
# Skipping AC005323.2: Gene not found
#
# Plotting AC110048.2
#
# Skipping AC110048.2: Gene not found
#
# Plotting AC022447.5
#
# Skipping AC022447.5: Gene not found
#
# Plotting AC025434.1
#
# Skipping AC025434.1: Gene not found
#
# Plotting LINC02756
#
# Skipping LINC02756: Gene not found
#
# Plotting PLEKHG4B
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL513487.1
#
# Skipping AL513487.1: Gene not found
#
# Plotting TRIM77
#
# Warning message:
# "Removed 17 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL158800.1
#
# Skipping AL158800.1: Gene not found
#
# Plotting HAPLN3
#
# Warning message:
# "Removed 5 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PCSK9
#
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL589743.4
#
# Skipping AL589743.4: Gene not found
#
# Plotting LINC02393
#
# Skipping LINC02393: Gene not found
#
# Plotting DNAJC22
#
# Warning message:
# "Removed 17 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC009835.1
#
# Skipping AC009835.1: Gene not found
#
# Plotting ADAM18
#
# Plotting PROX2
#
# Warning message:
# "Removed 14 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC008700.1
#
# Skipping AC008700.1: Gene not found
#
# Plotting ROBO1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting FRMD4B
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 6 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SV2C
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting GRIK1
#
# Warning message:
# "Removed 37 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting GNAL
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TRPC6
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 38 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SPOCK3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting MOXD1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting DOCK5
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 17 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting BCL11B
#
# Warning message:
# "Removed 154 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting FKBP5
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 15 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ZNF536
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting AC004158.1
#
# Warning message:
# "Removed 15 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TOX3
#
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting GAD2
#
# Warning message:
# "Removed 83 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ST18
#
# Plotting KIAA1217
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting NXPH1
#
# Plotting CTXN3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 55 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting KCNS3
#
# Plotting GAD1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 37 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SOX6
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 143 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting FRMPD1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting GYG2
#
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CHRNA7
#
# Warning message:
# "Removed 31 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01608
#
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting INHBA-AS1
#
# Skipping INHBA-AS1: Gene not found
#
# Plotting FOLH1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting MIR34AHG
#
# Skipping MIR34AHG: Gene not found
#
# Plotting LINC01170
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting SYTL5
#
# Warning message:
# "Removed 55 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MEPE
#
# Plotting GREB1L
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 6 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ERBB4
#
# Warning message:
# "Removed 65 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC074096.1
#
# Skipping AC074096.1: Gene not found
#
# Plotting ANKRD62
#
# Warning message:
# "Removed 17 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting DTHD1
#
# Warning message:
# "Removed 94 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL121578.3
#
# Skipping AL121578.3: Gene not found
#
# Plotting LINC00354
#
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SP9
#
# Warning message:
# "Removed 52 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting DOCK2
#
# Warning message:
# "Removed 77 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MYO5B
#
# Warning message:
# "Removed 11 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting NXPH2
#
# Plotting AC016687.2
#
# Skipping AC016687.2: Gene not found
#
# Plotting GRIK3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting SEMA3E
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 21 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AP003066.1
#
# Skipping AP003066.1: Gene not found
#
# Plotting MKX
#
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC016687.3
#
# Skipping AC016687.3: Gene not found
#
# Plotting AC097480.1
#
# Skipping AC097480.1: Gene not found
#
# Plotting AC012501.2
#
# Skipping AC012501.2: Gene not found
#
# Plotting TMTC4
#
# Warning message:
# "Removed 62 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting FER1L6-AS2
#
# Skipping FER1L6-AS2: Gene not found
#
# Plotting RPRM
#
# Warning message:
# "Removed 50 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ITGA6
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 89 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01163
#
# Plotting VAV2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 50 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02364
#
# Skipping LINC02364: Gene not found
#
# Plotting ARHGAP42
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 11 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting GALR1
#
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PARP4
#
# Plotting HAS2-AS1
#
# Skipping HAS2-AS1: Gene not found
#
# Plotting AC124254.2
#
# Skipping AC124254.2: Gene not found
#
# Plotting C22orf34
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 24 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01580
#
# Warning message:
# "Removed 9 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC023503.1
#
# Skipping AC023503.1: Gene not found
#
# Plotting LINC01850
#
# Skipping LINC01850: Gene not found
#
# Plotting LINC00402
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting AL353660.1
#
# Skipping AL353660.1: Gene not found
#
# Plotting LHFPL3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting NALCN-AS1
#
# Skipping NALCN-AS1: Gene not found
#
# Plotting LATS2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC109349.1
#
# Skipping AC109349.1: Gene not found
#
# Plotting SHROOM4
#
# Plotting C5AR2
#
# Plotting AC004852.2
#
# Skipping AC004852.2: Gene not found
#
# Plotting LINC00648
#
# Plotting ZCCHC24
#
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ATP12A
#
# Plotting LINC02737
#
# Skipping LINC02737: Gene not found
#
# Plotting SMOC1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02484
#
# Skipping LINC02484: Gene not found
#
# Plotting APCDD1
#
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OLIG1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 150 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting FER1L6-AS1
#
# Skipping FER1L6-AS1: Gene not found
#
# Plotting AL035425.3
#
# Skipping AL035425.3: Gene not found
#
# Plotting PDGFRA
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 12 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting BX284613.2
#
# Skipping BX284613.2: Gene not found
#
# Plotting AL450345.2
#
# Skipping AL450345.2: Gene not found
#
# Plotting LINC02192
#
# Skipping LINC02192: Gene not found
#
# Plotting HDAC1
#
# Warning message:
# "Removed 20 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ACSS1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting COL9A1
#
# Warning message:
# "Removed 72 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02472
#
# Skipping LINC02472: Gene not found
#
# Plotting ASB5
#
# Warning message:
# "Removed 86 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC093791.1
#
# Skipping AC093791.1: Gene not found
#
# Plotting DBX2
#
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SOX13
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 6 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL512308.1
#
# Skipping AL512308.1: Gene not found
#
# Plotting ZNF300
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting ADRA2A
#
# Plotting SLC12A7
#
# Plotting AL035425.1
#
# Skipping AL035425.1: Gene not found
#
# Plotting AC037486.1
#
# Skipping AC037486.1: Gene not found
#
# Plotting AL357614.1
#
# Skipping AL357614.1: Gene not found
#
# Plotting CHST3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 36 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting DDX60
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 86 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RTKN
#
# Warning message:
# "Removed 282 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TMEM255A
#
# Plotting VCAN-AS1
#
# Skipping VCAN-AS1: Gene not found
#
# Plotting GPR17
#
# Warning message:
# "Removed 103 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OLIG2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 75 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC092924.2
#
# Skipping AC092924.2: Gene not found
#
# Plotting HAS2
#
# Plotting IRGM
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting COL9A2
#
# Warning message:
# "Removed 49 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting VCAN
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 15 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC007106.2
#
# Skipping AC007106.2: Gene not found
#
# Plotting MKX-AS1
#
# Skipping MKX-AS1: Gene not found
#
# Plotting ADAMTS20
#
# Warning message:
# "Removed 32 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02450
#
# Skipping LINC02450: Gene not found
#
# Plotting NKX2-2
#
# Plotting AC097480.2
#
# Skipping AC097480.2: Gene not found
#
# Plotting CDC42EP5
#
# Warning message:
# "Removed 122 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SYTL4
#
# Warning message:
# "Removed 97 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02723
#
# Skipping LINC02723: Gene not found
#
# Plotting KLRC2
#
# Warning message:
# "Removed 40 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02283
#
# Skipping LINC02283: Gene not found
#
# Plotting AC129926.2
#
# Skipping AC129926.2: Gene not found
#
# Plotting ALDH1A1
#
# Plotting AL450352.1
#
# Skipping AL450352.1: Gene not found
#
# Plotting ALCAM
#
# Plotting MEGF10
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 34 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC084816.1
#
# Skipping AC084816.1: Gene not found
#
# Plotting LYPD6B
#
# Warning message:
# "Removed 30 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TSHZ2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 13 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL356295.1
#
# Skipping AL356295.1: Gene not found
#
# Plotting GABRG1
#
# Plotting AC092422.1
#
# Skipping AC092422.1: Gene not found
#
# Plotting AL109930.1
#
# Skipping AL109930.1: Gene not found
#
# Plotting GSG1L
#
# Warning message:
# "Removed 87 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CD53
#
# Plotting AC093607.1
#
# Skipping AC093607.1: Gene not found
#
# Plotting AC073578.2
#
# Skipping AC073578.2: Gene not found
#
# Plotting FGF10
#
# Plotting AC011416.4
#
# Skipping AC011416.4: Gene not found
#
# Plotting AL355672.1
#
# Skipping AL355672.1: Gene not found
#
# Plotting BARD1
#
# Plotting ST8SIA4
#
# Plotting ANKRD55
#
# Plotting ANXA1
#
# Plotting NHSL2
#
# Warning message:
# "Removed 40 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TDRD1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 5 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PRLR
#
# Warning message:
# "Removed 97 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC097512.1
#
# Skipping AC097512.1: Gene not found
#
# Plotting ROR2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting FSHR
#
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SLCO2A1
#
# Warning message:
# ...
# (`geom_segment()`)."
# Plotting AC093606.1
#
# Skipping AC093606.1: Gene not found
#
# Plotting TTC6
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 129 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PRRX1
#
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting HES1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting USH2A
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 30 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC079793.1
#
# Skipping AC079793.1: Gene not found
#
# Plotting OR8D1
#
# Plotting AC020930.1
#
# Skipping AC020930.1: Gene not found
#
# Plotting DOCK2
#
# Warning message:
# "Removed 77 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PCSK5
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 6 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting WDR86
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting AL445123.2
#
# Skipping AL445123.2: Gene not found
#
# Plotting LINC02465
#
# Skipping LINC02465: Gene not found
#
# Plotting AC096585.1
#
# Skipping AC096585.1: Gene not found
#
# Plotting AC090825.1
#
# Skipping AC090825.1: Gene not found
#
# Plotting CALCRL
#
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02360
#
# Skipping LINC02360: Gene not found
#
# Plotting ZNF878
#
# Warning message:
# "Removed 9 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC009236.2
#
# Warning message:
# "Removed 74 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OR8A1
#
# Warning message:
# "Removed 71 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC013549.1
#
# Skipping AC013549.1: Gene not found
#
# Plotting EDA
#
# Warning message:
# "Removed 101 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC011754.2
#
# Skipping AC011754.2: Gene not found
#
# Plotting AL359649.1
#
# Skipping AL359649.1: Gene not found
#
# Plotting LINC02125
#
# Skipping LINC02125: Gene not found
#
# Plotting KIF25
#
# Warning message:
# "Removed 272 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CBLN1
#
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01966
#
# Skipping LINC01966: Gene not found
#
# Plotting AC093585.1
#
# Skipping AC093585.1: Gene not found
#
# Plotting HIST1H3B
#
# Warning message:
# "Removed 7 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL049612.1
#
# Skipping AL049612.1: Gene not found
#
# Plotting AC044893.2
#
# Skipping AC044893.2: Gene not found
#
# Plotting AC007529.1
#
# Skipping AC007529.1: Gene not found
#
# Plotting LUM
#
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02419
#
# Skipping LINC02419: Gene not found
#
# Plotting AL161757.3
#
# Skipping AL161757.3: Gene not found
#
# Plotting ZG16B
#
# Skipping ZG16B: subscript out of bounds
#
# Plotting LINC02129
#
# Skipping LINC02129: Gene not found
#
# Plotting AC008440.2
#
# Skipping AC008440.2: Gene not found
#
# Plotting GHRH
#
# Warning message:
# "Removed 102 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting BRS3
#
# Plotting AL359813.2
#
# Skipping AL359813.2: Gene not found
#
# Plotting AL360175.1
#
# Skipping AL360175.1: Gene not found
#
# Plotting AL078581.3
#
# Skipping AL078581.3: Gene not found
#
# Plotting FABP4
#
# Skipping FABP4: subscript out of bounds
#
# Plotting AL136368.1
#
# Skipping AL136368.1: Gene not found
#
# Plotting AP001107.3
#
# Skipping AP001107.3: Gene not found
#
# Plotting LINC01228
#
# Warning message:
# "Removed 9 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC134312.6
#
# Skipping AC134312.6: Gene not found
#
# Plotting LINC01029
#
# Skipping LINC01029: subscript out of bounds
#
# Plotting ESAM
#
# Warning message:
# "Removed 76 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC00354
#
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting P2RY6
#
# Warning message:
# "Removed 76 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OR5AS1
#
# Skipping OR5AS1: subscript out of bounds
#
# Plotting AC011095.1
#
# Skipping AC011095.1: Gene not found
#
# Plotting MAP7D3
#
# Warning message:
# "Removed 14 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TMPRSS13
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 125 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting GRK5-IT1
#
# Skipping GRK5-IT1: Gene not found
#
# Plotting LINC02791
#
# Skipping LINC02791: Gene not found
#
# Plotting TMEM173
#
# Warning message:
# "Removed 28 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL031658.1
#
# Skipping AL031658.1: Gene not found
#
# Plotting OR52A5
#
# Warning message:
# "Removed 27 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CD300LG
#
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL121888.1
#
# Skipping AL121888.1: Gene not found
#
# Plotting HBD
#
# Warning message:
# "Removed 9 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LNCSRLR
#
# Skipping LNCSRLR: Gene not found
#
# Plotting IL10RA
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 29 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC010261.2
#
# Skipping AC010261.2: Gene not found
#
# Plotting CD83
#
# Plotting AC015522.1
#
# Skipping AC015522.1: Gene not found
#
# Plotting LINC02536
#
# Skipping LINC02536: Gene not found
#
# Plotting ANXA10
#
# Warning message:
# "Removed 97 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SCN4A
#
# Plotting BSND
#
# Plotting GABRR1
#
# Warning message:
# "Removed 92 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ENAM
#
# Skipping ENAM: subscript out of bounds
#
# Plotting AC025437.1
#
# Skipping AC025437.1: Gene not found
#
# Plotting NR5A1
#
# Warning message:
# "Removed 30 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL022344.1
#
# Skipping AL022344.1: Gene not found
#
# Plotting C10orf105
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 109 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting NUTM2E
#
# Warning message:
# "Removed 45 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ASCL2
#
# Warning message:
# "Removed 11 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OR10D3
#
# Skipping OR10D3: subscript out of bounds
#
# Plotting AC010547.2
#
# Skipping AC010547.2: Gene not found
#
# Plotting AC005696.3
#
# Skipping AC005696.3: Gene not found
#
# Plotting S1PR4
#
# Warning message:
# "Removed 32 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL137789.2
#
# Skipping AL137789.2: Gene not found
#
# Plotting ZMYND10-AS1
#
# Skipping ZMYND10-AS1: Gene not found
#
# Plotting AL158832.1
#
# Skipping AL158832.1: Gene not found
#
# Plotting GATA3
#
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OR8B12
#
# Skipping OR8B12: subscript out of bounds
#
# Plotting AP005380.1
#
# Skipping AP005380.1: Gene not found
#
# Plotting AL355602.1
#
# Skipping AL355602.1: Gene not found
#
# Plotting AC034159.2
#
# Skipping AC034159.2: Gene not found
#
# Plotting C4B
#
# Warning message:
# "Removed 74 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC010185.1
#
# Skipping AC010185.1: Gene not found
#
# Plotting LINC01077
#
# Skipping LINC01077: subscript out of bounds
#
# Plotting AC051619.8
#
# Skipping AC051619.8: Gene not found
#
# Plotting BCL6B
#
# Plotting LINC00958
#
# Warning message:
# "Removed 37 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC01954
#
# Skipping LINC01954: Gene not found
#
# Plotting AC091889.1
#
# Skipping AC091889.1: Gene not found
#
# Plotting AC044798.3
#
# Skipping AC044798.3: Gene not found
#
# Plotting IFIH1
#
# Warning message:
# "Removed 96 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting C6orf58
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 108 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC02249
#
# Skipping LINC02249: Gene not found
#
# Plotting PEAK3
#
# Skipping PEAK3: Gene not found
#
# Plotting KYNU
#
# Warning message:
# "Removed 15 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OR1L8
#
# Warning message:
# "Removed 38 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC116049.2
#
# Skipping AC116049.2: Gene not found
#
# Plotting LINC00615
#
# Plotting KMO
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 58 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MN1
#
# Warning message:
# "Removed 11 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC026391.1
#
# Skipping AC026391.1: Gene not found
#
# Plotting PRKCQ-AS1
#
# Warning message:
# "Removed 66 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC106774.4
#
# Skipping AC106774.4: Gene not found
#
# Plotting LINC01254
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 19 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC116096.1
#
# Skipping AC116096.1: Gene not found
#
# Plotting AC112236.3
#
# Skipping AC112236.3: Gene not found
#
# Plotting APOC4
#
# Warning message:
# "Removed 14 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL136372.2
#
# Skipping AL136372.2: Gene not found
#
# Plotting OR8D1
#
# Plotting LINC00604
#
# Skipping LINC00604: subscript out of bounds
#
# Plotting AP001922.1
#
# Skipping AP001922.1: Gene not found
#
# Plotting C11orf98
#
# Warning message:
# "Removed 78 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC021055.1
#
# Skipping AC021055.1: Gene not found
#
# Plotting FRG2B
#
# Plotting AC135782.3
#
# Skipping AC135782.3: Gene not found
#
# Plotting LINC02365
#
# Skipping LINC02365: Gene not found
#
# Plotting PENK
#
# Plotting AC008897.2
#
# Skipping AC008897.2: Gene not found
#
# Plotting AC091982.3
#
# Skipping AC091982.3: Gene not found
#
# Plotting TNR-IT1
#
# Skipping TNR-IT1: Gene not found
#
# Plotting AL121759.1
#
# Skipping AL121759.1: Gene not found
#
# Plotting ADGRL4
#
# Plotting NT5DC4
#
# Warning message:
# "Removed 78 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting NLRP7
#
# Plotting PI16
#
# Warning message:
# "Removed 32 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OR8A1
#
# Warning message:
# "Removed 71 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC104119.1
#
# Skipping AC104119.1: Gene not found
#
# Plotting HIC1
#
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL160269.1
#
# Skipping AL160269.1: Gene not found
#
# Plotting PLP2
#
# Warning message:
# "Removed 8 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC073225.1
#
# Skipping AC073225.1: Gene not found
#
# Plotting AC020658.3
#
# Skipping AC020658.3: Gene not found
#
# Plotting P2RY6
#
# Warning message:
# "Removed 76 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL157895.1
#
# Skipping AL157895.1: Gene not found
#
# Plotting LINC02213
#
# Skipping LINC02213: Gene not found
#
# Plotting C17orf107
#
# Warning message:
# "Removed 39 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting DKK1
#
# Warning message:
# "Removed 41 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AC084834.1
#
# Skipping AC084834.1: Gene not found
#
# Plotting AP001468.1
#
# Skipping AP001468.1: Gene not found
#
# Plotting AC138035.1
#
# Plotting DSCAM-AS1
#
# Skipping DSCAM-AS1: Gene not found
#
# Plotting OSGIN1
#
# Plotting AL137067.3
#
# Skipping AL137067.3: Gene not found
#
# Plotting GPR151
#
# Warning message:
# "Removed 53 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting FPR2
#
# Warning message:
# "Removed 46 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AL691403.1
#
# Skipping AL691403.1: Gene not found
#
# Plotting AC025430.1
#
# Skipping AC025430.1: Gene not found
#
# Plotting AC012170.3
#
# Skipping AC012170.3: Gene not found
#
# Plotting EDNRB-AS1
#
# Plotting PSG7
#
# Plotting AL590764.1
#
# Skipping AL590764.1: Gene not found
#
# Plotting AC007350.1
#
# Skipping AC007350.1: Gene not found
#
# Plotting FBLN1
#
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINC00498
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting TNFSF9
#
# Warning message:
# "Removed 141 rows containing missing values or values outside the scale range
# (`geom_segment()`)."

# %% [markdown]
# ### DEG RORB (both RBD vs HC and PD vs HC)

# %%
deg = read.csv("../../Signac_plots/PD/DEGs_PD_vs_HC_RORB_exn/gene_link_counts.csv")$gene

# %%
file_prefix <- "../../Signac_plots/HC/DEGs_RBD_PD_vs_HC_RORB_exn/"

# Create the directory if it doesn't exist
if (!dir.exists(file_prefix)) {
  dir.create(file_prefix, recursive = TRUE)  # 'recursive = TRUE' ensures parent directories are created if needed
  message(paste("Directory created:", file_prefix))
} else {
  message(paste("Directory already exists:", file_prefix))
}

save_link_counts(ifnb, deg, file_prefix)
# Out:
# Directory created: ../Signac_plots/HC/DEGs_RBD_PD_vs_HC_RORB_exn/
#
# Testing 117 genes and 148617 peaks
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "Each of the 2 combined objects has sequence levels not in the other:
#   - in 'x': GL000194.1, GL000195.1, GL000205.2, GL000218.1, GL000219.1, KI270711.1, KI270713.1, KI270721.1, KI270726.1, KI270727.1, KI270728.1, KI270731.1, KI270734.1, GL000009.2, GL000213.1
#   - in 'y': chrMT
#   Make sure to always combine/compare objects based on the same reference
#   genome (use suppressWarnings() to suppress this warning)."
# $df
#    seqnames     start       end  width strand       score     gene
# 1      chr1    812991   1309609 496619      *  0.05285895    ACAP3
# 2      chr1  13583913  13892792 308880      *  0.05089589     KAZN
# 3      chr1  13623127  13892792 269666      *  0.06969446     KAZN
# 4      chr1  13892792  13922610  29819      *  0.05151530     KAZN
# 5      chr1  13892792  14292751 399960      *  0.05622319     KAZN
# 6      chr1  13892792  14366530 473739      *  0.05224207     KAZN
# 7      chr1  36846076  37034129 188054      *  0.07663148    GRIK3
# 8      chr1  36919755  37034129 114375      *  0.05923475    GRIK3
# 9      chr1  36982494  37034129  51636      *  0.05728427    GRIK3
# 10     chr1  37034129  37363087 328959      *  0.10602847    GRIK3
# 11     chr1  39081316  39142796  61481      *  0.06187559    MACF1
# 12     chr1  58358551  58546734 188184      *  0.05475492     DAB1
# 13     chr1  58433138  58546734 113597      *  0.05174124     DAB1
# 14     chr1  58546734  58884953 338220      *  0.05109357     DAB1
# 15     chr2  24744319  25042130 297812      *  0.05656249    EFR3B
# 16     chr2 113211522 113235531  24010      *  0.08678253 PAX8-AS1
# 17     chr2 164843679 164955562 111884      *  0.05053228   COBLL1
# 18     chr2 164843679 165274841 431163      *  0.05137096   COBLL1
# 19     chr3  24829266  25174332 345067      *  0.06414562     RARB
# 20     chr3 132238409 132285410  47002      *  0.05397926    CPNE4
# 21     chr4 113761927 113979192 217266      *  0.05389428   CAMK2D
# 22     chr4 158315311 158410375  95065      *  0.05928471    RXFP1
# 23     chr5   9546075   9546140     66      *  0.06775259   SEMA5A
# 24     chr8  58966202  59119208 153007      *  0.08224351      TOX
# 25     chr8  59117810  59119208   1399      *  0.06038823      TOX
# 26     chr8  59119208  59119709    502      *  0.07984451      TOX
# 27    chr12  14946127  15322397 376271      *  0.05270451    PTPRO
# 28    chr12  14948931  15322397 373467      *  0.05590383    PTPRO
# 29    chr12  14952508  15322397 369890      *  0.05426863    PTPRO
# 30    chr12  81409699  81759553 349855      *  0.05285566   PPFIA2
# 31    chr12 110941301 111034024  92724      *  0.07262021     CUX2
# 32    chr12 111034024 111102316  68293      *  0.05525745     CUX2
# 33    chr12 111034024 111278992 244969      *  0.05881807     CUX2
# 34    chr16  22572632  22814177 241546      *  0.05087263   HS3ST2
# 35    chr16  22574164  22814177 240014      *  0.06981888   HS3ST2
# 36    chr16  22589486  22814177 224692      *  0.05801261   HS3ST2
# 37    chr16  22619888  22814177 194290      *  0.05763205   HS3ST2
# 38    chr16  22814177  23075080 260904      *  0.05695719   HS3ST2
# 39    chr16  25692026  25693673   1648      *  0.06493627   HS3ST4
# 40    chr16  25692026  26031365 339340      *  0.06086525   HS3ST4
# 41    chr16  81515504  81739097 223594      * -0.05927002    PLCG2
# 42    chr16  81625998  81739097 113100      *  0.05148982    PLCG2
# 43    chr16  81649238  81739097  89860      * -0.05172924    PLCG2
# 44    chr17  45914522  46361797 447276      *  0.05143421   ARL17B
# 45    chr17  46154205  46225374  71170      *  0.05574612   KANSL1
# 46    chr17  46154205  46361797 207593      *  0.07740491   ARL17B
# 47    chr17  46221001  46361797 140797      *  0.05475971   ARL17B
# 48    chr17  46225396  46361797 136402      *  0.06304350   ARL17B
# 49    chr17  46260004  46361797 101794      *  0.05299403   ARL17B
# 50    chr17  46266893  46361797  94905      *  0.05476103   ARL17B
# 51    chr17  46361797  46851958 490162      * -0.05009571   ARL17B
# 52    chr17  79516148  79598544  82397      * -0.06683567   RBFOX3
# 53    chr18  52340080  52340172     93      *  0.08961552      DCC
# 54    chr18  52340172  52342131   1960      *  0.05350316      DCC
# 55    chr18  52340172  52353789  13618      *  0.07776142      DCC
# 56    chr18  52340172  52407797  67626      *  0.06124432      DCC
# 57    chr18  52340172  52409489  69318      *  0.05783005      DCC
# 58    chr18  52340172  52717128 376957      *  0.07725204      DCC
# 59    chr18  57803101  58163447 360347      *  0.05165761   ATP8B1
# 60    chr20  52798853  52972407 173555      *  0.06902635    TSHZ2
# 61    chr20  52972407  52973598   1192      *  0.06016880    TSHZ2
# 62    chr20  52972407  53110030 137624      *  0.09505384    TSHZ2
# 63    chr22  32987484  33058372  70889      *  0.05162384     SYN3
# 64    chr22  33058372  33105796  47425      *  0.05005339     SYN3
# 65    chr22  33058372  33110480  52109      *  0.05302213     SYN3
# 66    chr22  33058372  33187304 128933      *  0.05070419     SYN3
# 67     chrY  12372250  12701231 328982      *  0.12365101    USP9Y
# 68     chrY  12418258  12701231 282974      *  0.06252823    USP9Y
# 69     chrY  12546912  12701231 154320      *  0.07395500    USP9Y
# 70     chrY  12662162  12701231  39070      *  0.06013675    USP9Y
# 71     chrY  12663391  12701231  37841      *  0.06347503    USP9Y
# 72     chrY  12701231  12730009  28779      *  0.05052195    USP9Y
# 73     chrY  12701231  12905296 204066      *  0.11260151    USP9Y
# 74     chrY  12701231  12941991 240761      *  0.06592612    USP9Y
# 75     chrY  19075985  19077416   1432      *  0.06272579   TTTY14
# 76     chrY  19077416  19077525    110      *  0.09672993   TTTY14
# 77     chrY  19077416  19405826 328411      *  0.06394078   TTTY14
# 78     chrY  19077416  19567274 489859      *  0.08892748   TTTY14
#                         peak    zscore       pvalue
# 1         chr1-812528-813454  3.980434 3.439474e-05
# 2     chr1-13583110-13584716  2.552734 5.344051e-03
# 3     chr1-13622160-13624094  2.889993 1.926253e-03
# 4     chr1-13922099-13923121  2.663100 3.871225e-03
# 5     chr1-14292145-14293357  2.942887 1.625834e-03
# 6     chr1-14366037-14367022  2.680479 3.675840e-03
# 7     chr1-36845258-36846894  4.817343 7.274122e-07
# 8     chr1-36919130-36920380  4.091295 2.144852e-05
# 9     chr1-36981503-36983485  4.368677 6.250069e-06
# 10    chr1-37362515-37363658  7.351313 9.813450e-14
# 11    chr1-39142267-39143325  4.657968 1.596732e-06
# 12    chr1-58358022-58359079  2.332068 9.848547e-03
# 13    chr1-58432520-58433755  2.430981 7.529011e-03
# 14    chr1-58884456-58885449  1.969077 2.447215e-02
# 15    chr2-24743792-24744845  4.770144 9.204702e-07
# 16  chr2-113235044-113236017  6.714719 9.421481e-12
# 17  chr2-164954931-164956192  2.350287 9.379463e-03
# 18  chr2-165274246-165275435  3.022674 1.252762e-03
# 19    chr3-24828781-24829750  3.873086 5.373291e-05
# 20  chr3-132237914-132238904  2.895241 1.894339e-03
# 21  chr4-113978162-113980221  3.353663 3.987465e-04
# 22  chr4-158409890-158410859  2.928648 1.702198e-03
# 23      chr5-9545437-9546843  5.022697 2.547548e-07
# 24    chr8-58965657-58966746  3.760669 8.472977e-05
# 25    chr8-59117298-59118322  2.916676 1.768915e-03
# 26    chr8-59119071-59120346  4.261994 1.013056e-05
# 27   chr12-14945591-14946662  2.497374 6.255841e-03
# 28   chr12-14948439-14949422  2.812533 2.457651e-03
# 29   chr12-14951988-14953028  2.576011 4.997376e-03
# 30   chr12-81409167-81410231  2.102069 1.777361e-02
# 31 chr12-110940695-110941907  4.412933 5.098984e-06
# 32 chr12-111101738-111102893  2.965417 1.511365e-03
# 33 chr12-111278394-111279590  3.171137 7.592188e-04
# 34   chr16-22572108-22573156  2.583578 4.889074e-03
# 35   chr16-22573579-22574749  3.459163 2.709287e-04
# 36   chr16-22589092-22589880  3.973072 3.547581e-05
# 37   chr16-22619299-22620476  3.086652 1.012122e-03
# 38   chr16-23074417-23075742  3.085621 1.015637e-03
# 39   chr16-25693358-25693988  4.435353 4.596079e-06
# 40   chr16-26030834-26031895  4.187130 1.412521e-05
# 41   chr16-81515049-81515958 -1.889943 2.938278e-02
# 42   chr16-81625411-81626585  2.205070 1.372459e-02
# 43   chr16-81648602-81649873 -1.919201 2.747945e-02
# 44   chr17-45913938-45915106  2.849372 2.190282e-03
# 45   chr17-46153665-46154745  3.104004 9.546041e-04
# 46   chr17-46153665-46154745  3.399761 3.372239e-04
# 47   chr17-46220472-46221529  2.463098 6.887112e-03
# 48   chr17-46224854-46225938  3.295694 4.908946e-04
# 49   chr17-46259214-46260794  2.612217 4.497851e-03
# 50   chr17-46266348-46267437  3.380073 3.623326e-04
# 51   chr17-46851005-46852911 -2.686618 3.608970e-03
# 52   chr17-79598053-79599034 -4.078679 2.264614e-05
# 53   chr18-52339527-52340633  4.266696 9.919446e-06
# 54   chr18-52341637-52342624  2.565505 5.151286e-03
# 55   chr18-52353233-52354345  3.370963 3.745298e-04
# 56   chr18-52407357-52408236  3.570234 1.783309e-04
# 57   chr18-52408561-52410416  2.939591 1.643228e-03
# 58   chr18-52716469-52717787  3.875740 5.315048e-05
# 59   chr18-58162950-58163943  3.230169 6.185858e-04
# 60   chr20-52797797-52799908  3.385316 3.554813e-04
# 61   chr20-52972978-52974217  3.164963 7.755146e-04
# 62   chr20-53109343-53110717  4.690107 1.365308e-06
# 63   chr22-32986998-32987970  2.234172 1.273587e-02
# 64   chr22-33105252-33106339  2.502701 6.162481e-03
# 65   chr22-33109664-33111295  1.863047 3.122781e-02
# 66   chr22-33186846-33187761  2.983408 1.425287e-03
# 67    chrY-12371603-12372897  5.943317 1.396555e-09
# 68    chrY-12417692-12418823  2.662140 3.882284e-03
# 69    chrY-12546425-12547398  2.887263 1.943049e-03
# 70    chrY-12661685-12662639  2.622906 4.359164e-03
# 71    chrY-12662888-12663893  2.458644 6.973140e-03
# 72    chrY-12729496-12730522  2.010835 2.217147e-02
# 73    chrY-12904368-12906223  5.116547 1.555898e-07
# 74    chrY-12941517-12942465  2.611067 4.513005e-03
# 75    chrY-19075461-19076509  2.588866 4.814626e-03
# 76    chrY-19076877-19078172  4.488938 3.578963e-06
# 77    chrY-19405344-19406308  2.611634 4.505540e-03
# 78    chrY-19566837-19567711  3.636539 1.381628e-04
#
# $gene_link_counts
# # A tibble: 29 × 2
#    gene   link_count
#    <chr>       <int>
#  1 ACAP3           1
#  2 ARL17B          7
#  3 ATP8B1          1
#  4 CAMK2D          1
#  5 COBLL1          2
#  6 CPNE4           1
#  7 CUX2            3
#  8 DAB1            3
#  9 DCC             6
# 10 EFR3B           1
# # ℹ 19 more rows

# %%
file_prefix <- "../../Signac_plots/HC/DEGs_RBD_PD_vs_HC_RORB_exn/"

# Create the directory if it doesn't exist
if (!dir.exists(file_prefix)) {
  dir.create(file_prefix, recursive = TRUE)  # 'recursive = TRUE' ensures parent directories are created if needed
  message(paste("Directory created:", file_prefix))
} else {
  message(paste("Directory already exists:", file_prefix))
}

plot_coverage(ifnb, deg, file_prefix)
# Out:
# Directory already exists: ../Signac_plots/HC/DEGs_RBD_PD_vs_HC_RORB_exn/
#
# Testing 117 genes and 148617 peaks
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "Each of the 2 combined objects has sequence levels not in the other:
#   - in 'x': GL000194.1, GL000195.1, GL000205.2, GL000218.1, GL000219.1, KI270711.1, KI270713.1, KI270721.1, KI270726.1, KI270727.1, KI270728.1, KI270731.1, KI270734.1, GL000009.2, GL000213.1
#   - in 'y': chrMT
#   Make sure to always combine/compare objects based on the same reference
#   genome (use suppressWarnings() to suppress this warning)."
# Plotting ABLIM2
#
# Warning message:
# "Removed 90 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ABR
#
# Warning message:
# "Removed 122 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ACAP3
#
# Warning message:
# "Removed 32 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ADCY9
#
# Plotting AGAP1
#
# Plotting ANKRD36
#
# Warning message:
# "Removed 63 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ARL17B
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 124 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ATP8B1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 368 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting AUTS2
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 45 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting BDH1
#
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting BMPER
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 20 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CABP1
#
# Warning message:
# "Removed 56 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CACNA1A
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 5 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CACNG8
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 5 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CAMK1D
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 20 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CAMK2A
#
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CAMK2D
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting CATSPER2
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 210 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CCDC144A
#
# Warning message:
# "Removed 22 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CELF5
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 8 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CHD5
#
# Warning message:
# "Removed 59 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CMTM8
#
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CNTN3
#
# Plotting COBLL1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 188 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting COL12A1
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 15 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CPNE4
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 18 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CRTC1
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 74 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting CSMD1
#
# Plotting CUX2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 56 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting DAB1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 54 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting DCC
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting DGCR9
#
# Warning message:
# "Removed 5 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting DGKZ
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 29 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting DNM1
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 7 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ECE1
#
# Warning message:
# "Removed 306 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting EFR3B
#
# Warning message:
# "Removed 12 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting EPHA3
#
# Plotting FSTL4
#
# Plotting GRIK3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting GSTO2
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 163 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting GTF2IRD1
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 147 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting HERC1
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 124 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting HS3ST2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting HS3ST4
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting IGSF21
#
# Warning message:
# "Removed 63 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting KANSL1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 82 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting KAZN
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 27 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting KCNAB2
#
# Warning message:
# "Removed 118 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting KCND3
#
# Warning message:
# "Removed 18 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting KCNIP4
#
# Warning message:
# "Removed 27 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting KCNQ2
#
# Warning message:
# "Removed 14 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting KDM4B
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 72 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting KHDRBS2
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Plotting KIRREL3
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 7 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting LINGO2
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Plotting LUC7L
#
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 6 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MACF1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MAPT
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 41 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MEF2C
#
# Warning message:
# "Removed 25 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MEG3
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 16 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MEIS3
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MET
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MGAT5B
#
# Warning message:
# "Removed 218 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MIAT
#
# Warning message:
# "Removed 38 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting MROH7
#
# Warning message:
# "Removed 13 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OSBP2
#
# Warning message:
# "Removed 25 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OSBPL10
#
# Warning message:
# "Removed 22 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting OTOGL
#
# Warning message:
# "Removed 7 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting P2RX7
#
# Plotting PAPSS2
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PAX8-AS1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PCBP1-AS1
#
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PDE1A
#
# Warning message:
# "Removed 51 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PDE2A
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Plotting PDXK
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PHACTR1
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 23 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PIGL
#
# Warning message:
# "Removed 290 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PKD1
#
# Warning message:
# "Removed 50 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PKNOX2
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 7 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PLCG2
#
# Warning message:
# "Removed 56 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PLD3
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 10 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PPFIA2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 54 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PPIP5K1
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 185 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PPP6R2
#
# Warning message:
# "Removed 181 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PRKAR1B
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PTPRO
#
# Warning message:
# "Removed 30 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting PTPRS
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 51 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RAB11FIP3
#
# Warning message:
# "Removed 29 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RAB3D
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Plotting RAB40C
#
# Warning message:
# "Removed 13 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RAD9A
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 3 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RARB
#
# Warning message:
# "Removed 5 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RBFOX1
#
# Warning message:
# "Removed 4 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RBFOX3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 13 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RTN4RL1
#
# Warning message:
# "Removed 41 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RXFP1
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 76 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting RYR2
#
# Plotting SEMA5A
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting SH3GL1
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 35 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SLC22A10
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 195 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SLC39A11
#
# Warning message:
# "Removed 47 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SLIT1
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 25 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting SPTBN4
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Plotting SRRM3
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Plotting SUSD1
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Plotting SYN3
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 93 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TENM3
#
# Warning message:
# "Removed 14 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TMEM266
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 215 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TOX
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Plotting TOX3
#
# Warning message:
# "Removed 2 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TSHZ2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 13 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TSHZ3
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Plotting TTC39C
#
# Warning message:
# "Removed 277 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting TTTY14
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 17 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting UNC13A
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# Warning message:
# "Removed 136 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting USP9Y
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 141 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Plotting ZBTB46
#
# Warning message:
# "Removed 238 rows containing missing values or values outside the scale range
# (`geom_segment()`)."

# %% [markdown]
# ### Save individually for viz

# %%
file_prefix <- "../../Signac_plots/HC/DEGs_RBD_PD_vs_HC_RORB_exn/"

# Create the directory if it doesn't exist
if (!dir.exists(file_prefix)) {
  dir.create(file_prefix, recursive = TRUE)  # 'recursive = TRUE' ensures parent directories are created if needed
  message(paste("Directory created:", file_prefix))
} else {
  message(paste("Directory already exists:", file_prefix))
}

one <- c("CUX2")
plot_coverage(ifnb, one, file_prefix)
# Out:
# Directory already exists: ../Signac_plots/HC/DEGs_RBD_PD_vs_HC_RORB_exn/
#
# Testing 1 genes and 148617 peaks
#
# Warning message in .merge_two_Seqinfo_objects(x, y):
# "Each of the 2 combined objects has sequence levels not in the other:
#   - in 'x': GL000194.1, GL000195.1, GL000205.2, GL000218.1, GL000219.1, KI270711.1, KI270713.1, KI270721.1, KI270726.1, KI270727.1, KI270728.1, KI270731.1, KI270734.1, GL000009.2, GL000213.1
#   - in 'y': chrMT
#   Make sure to always combine/compare objects based on the same reference
#   genome (use suppressWarnings() to suppress this warning)."
# Plotting CUX2
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Warning message:
# "Removed 56 rows containing missing values or values outside the scale range
# (`geom_segment()`)."
# Warning message:
# "Removed 1 row containing missing values or values outside the scale range
# (`geom_segment()`)."
